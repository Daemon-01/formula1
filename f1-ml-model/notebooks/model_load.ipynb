# %%
import joblib
import os
import pandas as pd 
import numpy as np
from sklearn.metrics import mean_absolute_error

model_path = r"C:\Users\ADMIN\Downloads\Formula1\f1-ml-model\models"
for file in os.listdir(model_path):
    print(f"  - {file}")
model = joblib.load(model_path)
# feature_name = model[:-1].get_feature_names_out()
# print(feature_name.tolist())
# Out:
#   - f1_race_model.joblib
